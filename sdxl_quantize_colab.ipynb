# %% [markdown]
# # SDXL GGUF Quantize Tool - Colab Edition
# Run this notebook to launch the Gradio interface directly in Google Colab.

# %%
# !git clone https://github.com/magekinnarus/SDXL_GGUF_Quantize_Tool.git
# %cd SDXL_GGUF_Quantize_Tool

# !pip install -r requirements.txt
# !pip install -r requirements-gradio.txt

# %% [markdown]
# ### Optional: Mount Google Drive
# Run this cell if you want to read/write models directly to your Google Drive to save Colab space!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
if '/content/SDXL_GGUF_Quantize_Tool' not in sys.path:
    sys.path.append('/content/SDXL_GGUF_Quantize_Tool')

import app_gradio
app_gradio.demo.launch(inline=True, share=True, debug=True, height=800)
